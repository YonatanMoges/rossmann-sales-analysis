# %%
# Import custom module
import sys
import os
sys.path.insert(0,os.path.abspath("../scripts"))
import eda as eda
import importlib
importlib.reload(eda)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Load data
store_data = pd.read_csv('../data/store.csv')
test_data = pd.read_csv('../data/test.csv')
train_data = pd.read_csv('../data/train.csv')
sample_submission_data = pd.read_csv('../data/sample_submission.csv')

# Merge training and test data for combined analysis (if necessary)
combined_data = pd.merge(train_data, store_data, on='Store', how='left')


eda.analyze_promo_distribution(train_data, test_data)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19468\3582230344.py:22: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv('../data/train.csv')
# 2024-09-20 00:57:53,885 - INFO - Promotion distribution analyzed.
