# %%
# Import custom module
import sys
import os
sys.path.insert(0,os.path.abspath("../scripts"))
import eda as eda
import importlib
importlib.reload(eda)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Load data
store_data = pd.read_csv('../data/store.csv')
test_data = pd.read_csv('../data/test.csv')
train_data = pd.read_csv('../data/train.csv')
sample_submission_data = pd.read_csv('../data/sample_submission.csv')

# Merge training and test data for combined analysis (if necessary)
combined_data = pd.merge(train_data, store_data, on='Store', how='left')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15736\992797178.py:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv('../data/train.csv')

# %%
combined_data = eda.clean_data(combined_data)
combined_data.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1            0
# 1      2          4 2015-07-31   6064        625     1      1            0
# 2      3          4 2015-07-31   8314        821     1      1            0
# 3      4          4 2015-07-31  13995       1498     1      1            0
# 4      5          4 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType  ... CompetitionDistance  \
# 0              1         c  ...              1270.0
# 1              1         a  ...               570.0
# 2              1         a  ...             14130.0
# 3              1         c  ...               620.0
# 4              1         a  ...             29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# 2                       12.0                    2006.0       1
# 3                        9.0                    2009.0       0
# 4                        4.0                    2015.0       0
#
#    Promo2SinceWeek  Promo2SinceYear    PromoInterval Day  Month  Year
# 0              0.0              0.0                0  31      7  2015
# 1             13.0           2010.0  Jan,Apr,Jul,Oct  31      7  2015
# 2             14.0           2011.0  Jan,Apr,Jul,Oct  31      7  2015
# 3              0.0              0.0                0  31      7  2015
# 4              0.0              0.0                0  31      7  2015
#
# [5 rows x 21 columns]

# %% [markdown]
# Distribution in training and test sets

# %%
eda.analyze_promo_distribution(train_data, test_data)
# Out:
# 2024-09-20 02:09:07,763 - INFO - Promotion distribution analyzed.

# %% [markdown]
# Sales before, during and after holidays

# %%
eda.analyze_sales_behavior(combined_data)
# Out:
# 2024-09-20 02:09:08,067 - INFO - Sales behavior analyzed.

# %% [markdown]
# Seasonal purchase behaviors

# %%
# Call the function
eda.analyze_seasonal_purchase_behaviors(combined_data)
# Out:
# 2024-09-20 02:09:08,532 - INFO - Seasonal purchase behaviors analyzed.
