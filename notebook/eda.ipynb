# %%
# Import custom module
import sys
import os
sys.path.insert(0,os.path.abspath("../scripts"))
import eda as eda
import importlib
importlib.reload(eda)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Load data
store_data = pd.read_csv('../data/store.csv')
test_data = pd.read_csv('../data/test.csv')
train_data = pd.read_csv('../data/train.csv')
sample_submission_data = pd.read_csv('../data/sample_submission.csv')

# Merge training and test data for combined analysis (if necessary)
combined_data = pd.merge(train_data, store_data, on='Store', how='left')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7640\992797178.py:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv('../data/train.csv')

# %%
combined_data = eda.clean_data(combined_data)
combined_data.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1            0
# 1      2          4 2015-07-31   6064        625     1      1            0
# 2      3          4 2015-07-31   8314        821     1      1            0
# 3      4          4 2015-07-31  13995       1498     1      1            0
# 4      5          4 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType  ... CompetitionOpenSinceMonth  \
# 0              1         c  ...                       9.0
# 1              1         a  ...                      11.0
# 2              1         a  ...                      12.0
# 3              1         c  ...                       9.0
# 4              1         a  ...                       4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              0.0              0.0
# ...

# %% [markdown]
# Distribution in training and test sets

# %%
eda.analyze_promo_distribution(train_data, test_data)
# Out:
# 2024-09-21 16:29:38,502 - INFO - Promotion distribution analyzed.

# %% [markdown]
# Sales before, during and after holidays

# %%
eda.analyze_sales_behavior(combined_data)

# %% [markdown]
# Seasonal purchase behaviors

# %%
# Call the function
eda.analyze_seasonal_purchase_behaviors(combined_data)
# Out:
# 2024-09-21 16:29:39,288 - INFO - Seasonal purchase behaviors analyzed.

# %% [markdown]
# Analyzing Correlation Between Sales and Customers

# %%
# Call the function
eda.analyze_correlation(combined_data)
# Out:
# 2024-09-21 16:29:39,388 - INFO - Correlation between Sales and Customers analyzed.
# Correlation between Sales and Customers: 0.8947107733017018

# %% [markdown]
# Analyzing Promotion Impact

# %%
eda.analyze_promo_impact(combined_data)
# Out:
# 2024-09-21 16:29:39,628 - INFO - Promotion impact analyzed.

# %% [markdown]
# Analyzing Customer Behavior During Store Opening and Closing Times

# %%
eda.analyze_customer_behavior(combined_data)
# Out:
# 2024-09-21 16:29:40,231 - INFO - Customer behavior analyzed.

# %% [markdown]
# Analyzing Store Opening Hours and Weekend Sales

# %%
# Call the function
eda.analyze_store_opening_hours(combined_data)
# Out:
# 2024-09-21 16:29:40,965 - INFO - Store opening hours analyzed.

# %% [markdown]
# Analyzing Assortment Impact

# %%
eda.analyze_assortment_impact(combined_data)
# Out:
# 2024-09-21 16:29:41,195 - INFO - Assortment impact analyzed.

# %% [markdown]
# Analyzing Competitor Distance

# %%
eda.analyze_competitor_distance(combined_data)

# %% [markdown]
# Analyzing Impact of New Competitors

# %%
eda.analyze_new_competitors(combined_data)
# Out:
# T-statistic: 2.8213752236309126
# P-value: 0.005298442459744605
